# %% [markdown]
# # A million song: Milestone 2
#
# ## Goals
#
# To do sentiment analysis on music genre.
#
#     *Stemming is very commonly used in this kind of text analysis task. For statistical purposes, it is more interesting to treat "cry", "cried", and "crying" as instances of the same thing, rather than treating them as distinct, unrelated tokens. We use a simple, well-known stemming algorithm (Porter2) (which for this example maps all these words to "cri")"

# %%
#Imports
# %matplotlib inline
import numpy as np
import pandas as pd
import re
import sklearn
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn import linear_model
from sklearn.pipeline import Pipeline
from mpl_toolkits.mplot3d import Axes3D
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
import sklearn.metrics as skm
from IPython.display import display, HTML

# %% [markdown]
# Importing the most used words and their count inside the dataset. A bit of data wrangling is necessary

# %%
#Importing the data, putting it in a DataFrame
full_word_list = pd.read_table('Data/full_word_list.txt')
#Renaming the columns
full_word_list.columns = ['Word']
#Extracting word count
full_word_list['Count'] = pd.to_numeric(full_word_list['Word'].str.split('<SEP>', expand=True)[1])
#Extracted words that were used
full_word_list['Word'] = full_word_list['Word'].str.split('<SEP>', expand=True)[0]
#Dropping rows we will not use
full_word_list = full_word_list.drop(full_word_list.index[:6])

display(full_word_list.head(20))
# Out:
#     Word      Count
# 6      i  2078808.0
# 7    the  1863782.0
# 8    you  1744257.0
# 9     to  1067578.0
# 10   and  1055748.0
# 11     a   974499.0
# 12    it   821152.0
# 13    me   771755.0
# 14   not   735396.0
# 15    in   626410.0
# 16    my   611942.0
# 17    is   595735.0
# 18    of   540064.0
# 19  that   474535.0
# 20    do   470946.0
# 21  your   463681.0
# 22    on   419354.0
# 23    am   407827.0
# 24    we   393787.0
# 25   are   381331.0

# %%
#Importing the text file in a DataFrame, removing exceptions (bad data)
matches = pd.read_table('Data/mxm_779k_matches.txt', error_bad_lines=False)
#Changing the column's title in order to be clearer
matches.columns = ['Raw']
#Getting the Tid
matches['Tid'] = matches['Raw'].str.split('<SEP>', expand=True)[0]
#Extracting artist names
matches['Artist_Name'] = matches['Raw'].str.split('<SEP>', expand=True)[1]
#Extracting titles
matches['Title'] = matches['Raw'].str.split('<SEP>', expand=True)[2]
#Extractign MXM_Tid
matches['MXM_Tid'] = matches['Raw'].str.split('<SEP>', expand=True)[3]

#Second artist name
matches['Artist_again'] = matches['Raw'].str.split('<SEP>', expand=True)[4]

#Second title
matches['Title_again'] = matches['Raw'].str.split('<SEP>', expand=True)[5]

#Dropping rows we do not need
matches = matches.drop(matches.index[:17])
# Out:
# b'Skipping line 60821: expected 1 fields, saw 2\nSkipping line 126702: expected 1 fields, saw 2\n'
# b'Skipping line 580629: expected 1 fields, saw 2\nSkipping line 632526: expected 1 fields, saw 2\n'

# %%
display(matches.head(20))
# Out:
#                                                   Raw                 Tid  \
# 17  TRMMMKD128F425225D<SEP>Karkkiautomaatti<SEP>Ta...  TRMMMKD128F425225D
# 18  TRMMMRX128F93187D9<SEP>Hudson Mohawke<SEP>No O...  TRMMMRX128F93187D9
# 19  TRMMMCH128F425532C<SEP>Yerba Brava<SEP>Si Vos ...  TRMMMCH128F425532C
# 20  TRMMMXN128F42936A5<SEP>David Montgomery<SEP>Sy...  TRMMMXN128F42936A5
# 21  TRMMMBB12903CB7D21<SEP>Kris Kross<SEP>2 Da Bea...  TRMMMBB12903CB7D21
# 22  TRMMMHY12903CB53F1<SEP>Joseph Locke<SEP>Goodby...  TRMMMHY12903CB53F1
# 23  TRMMMNS128F93548E1<SEP>3 Gars Su'l Sofa<SEP>L'...  TRMMMNS128F93548E1
# 24  TRMMMXJ12903CBF111<SEP>Jorge Negrete<SEP>El hi...  TRMMMXJ12903CBF111
# 25  TRMMMBW128F4260CAE<SEP>Tiger Lou<SEP>Pilots<SE...  TRMMMBW128F4260CAE
# 26  TRMMMXI128F4285A3F<SEP>Waldemar Bastos<SEP>N G...  TRMMMXI128F4285A3F
# 27  TRMMMKI128F931D80D<SEP>Lena Philipsson<SEP>006...  TRMMMKI128F931D80D
# 28  TRMMMUT128F42646E8<SEP>Shawn Colvin<SEP>(Looki...  TRMMMUT128F42646E8
# 29  TRMMMQY128F92F0EA3<SEP>Dying Fetus<SEP>Ethos o...  TRMMMQY128F92F0EA3
# 30  TRMMMTK128F424EF7C<SEP>Emery<SEP>Rock-N-Rule<S...  TRMMMTK128F424EF7C
# 31  TRMMMQV12903CA201E<SEP>Rev. Timothy Wright<SEP...  TRMMMQV12903CA201E
# 32  TRMMMPN128F426610E<SEP>Nicolette<SEP>Nervous<S...  TRMMMPN128F426610E
# 33  TRMMMNO128F93539AA<SEP>Martin Sexton<SEP>In Th...  TRMMMNO128F93539AA
# 34  TRMMMTG128F426B5BB<SEP>Craze<SEP>Fuckin Ethic ...  TRMMMTG128F426B5BB
# 35  TRMMMPJ128F9306985<SEP>Christian Castro<SEP>Tu...  TRMMMPJ128F9306985
# 36  TRMMMRZ128F4265EB4<SEP>Aerosmith<SEP>I'm Ready...  TRMMMRZ128F4265EB4
#
#             Artist_Name                                              Title  \
# 17     Karkkiautomaatti                                        Tanssi vaan
# 18       Hudson Mohawke                                  No One Could Ever
# 19          Yerba Brava                                      Si Vos Querés
# 20     David Montgomery  Symphony No. 1 G minor "Sinfonie Serieuse"/All...
# 21           Kris Kross                                  2 Da Beat Ch'yall
# 22         Joseph Locke                                            Goodbye
# 23     3 Gars Su'l Sofa                                      L'antarctique
# 24        Jorge Negrete                                 El hijo del pueblo
# 25            Tiger Lou                                             Pilots
# 26      Waldemar Bastos                                             N Gana
# 27      Lena Philipsson                                                006
# 28         Shawn Colvin                (Looking For) The Heart Of Saturday
# 29          Dying Fetus                                  Ethos of Coercion
# 30                Emery                                        Rock-N-Rule
# 31  Rev. Timothy Wright                                     I Made It Over
# 32            Nicolette                                            Nervous
# 33        Martin Sexton                                     In The Journey
# 34                Craze                          Fuckin Ethic People (999)
# 35     Christian Castro                                 Tu Vida Con La Mía
# 36            Aerosmith                                          I'm Ready
#
#     MXM_Tid         Artist_again  \
# 17  4418550     Karkkiautomaatti
# 18  8898149       Hudson Mohawke
# 19  9239868          Yerba Brava
# 20  5346741        Franz Berwald
# 21  2511405           Kris Kross
# 22   793273        Joseph LoDuca
# 23  7503609     3 gars su'l sofa
# 24  7362052        Jorge Negrete
# 25  7833814            Tiger Lou
# 26  2320200      Waldemar Bastos
# 27  4280619      Lena Philipsson
# 28   674743         Shawn Colvin
# 29  8851472          Dying Fetus
# 30  9855482                Emery
# 31   610698  Rev. Timothy Wright
# 32   721926            Nicolette
# 33  1860322        Martin Sexton
# 34   620542             DJ Craze
# 35  3578541     Christian Castro
# 36  2124234            Aerosmith
#
#                                           Title_again
# 17                                        Tanssi vaan
# 18                                  No One Could Ever
# 19                                      Si vos queres
# 20  Symphony No. 1 in G minor "Sinfonie Sérieuse":...
# 21                                  2 Da Beat Ch'yall
# 22                                            Goodbye
# 23                                      L'Antarctique
# 24                                 El hijo del pueblo
# 25                                             Pilots
# 26                                             N Gana
# 27                                                006
# 28          (Looking for) The Heart of Saturday Night
# 29                                  Ethos of Coercion
# 30                                        Rock-N-Rule
# 31                                     I Made It Over
# 32                                            Nervous
# 33                                     In the Journey
# 34                          Fuckin Ethic People (999)
# 35                                 Tu vida con la mia
# 36                                          I'm Ready

# %% [markdown]
# From the dataset, there was some given metadata:
# - The total word count is 55 163 335
# - There are 498 134 unique words
#
# Those parameters could be usefull for our sentiment analysis, thus why we implement them.

# %%
Word_count_total = 55163335
Unique_word_number = 498134

# %%
#Computing the percentage of occurence:
full_word_list['Occurence_percentage'] = (full_word_list['Count']/ Word_count_total)*100
display(full_word_list.head(20))

#Showing the percentage of the 100 most used word over the total
display(full_word_list['Occurence_percentage'][:100].sum())
# Out:
#     Word      Count  Occurence_percentage
# 6      i  2078808.0              3.768460
# 7    the  1863782.0              3.378661
# 8    you  1744257.0              3.161986
# 9     to  1067578.0              1.935304
# 10   and  1055748.0              1.913858
# 11     a   974499.0              1.766570
# 12    it   821152.0              1.488583
# 13    me   771755.0              1.399036
# 14   not   735396.0              1.333125
# 15    in   626410.0              1.135555
# 16    my   611942.0              1.109327
# 17    is   595735.0              1.079947
# 18    of   540064.0              0.979027
# 19  that   474535.0              0.860236
# 20    do   470946.0              0.853730
# 21  your   463681.0              0.840560
# 22    on   419354.0              0.760204
# 23    am   407827.0              0.739308
# 24    we   393787.0              0.713856
# 25   are   381331.0              0.691276
# 52.8380581050801

# %% [markdown]
# One can notice that the most used first 100 words are already representing half of total count.
